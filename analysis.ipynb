# %% [markdown]
# # Phone sales analysis

# %% [markdown]
# First, we will need to load the dataset and import the necessities.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Order_details(masked).csv")
df.head()
# Out:
#        Name                      Email  \
# 0  PERSON_1         PERSON_1@gmail.com
# 1  PERSON_2  PERSON_2@tataprojects.com
# 2  PERSON_3         PERSON_3@gmail.com
# 3  PERSON_4         PERSON_4@gmail.com
# 4  PERSON_5         PERSON_5@gmail.com
#
#                                        Product     Transaction Date
# 0                                   PRODUCT_75  01/03/2021 00:47:26
# 1                                   PRODUCT_75  01/03/2021 02:04:07
# 2                                   PRODUCT_63  01/03/2021 09:10:43
# 3                                   PRODUCT_63  01/03/2021 09:49:48
# 4  PRODUCT_34,PRODUCT_86,PRODUCT_57,PRODUCT_89  01/03/2021 10:56:46

# %%
df['Time']  = pd.to_datetime(df["Transaction Date"])
df["Hour"]  = (df['Time']).dt.hour
df.drop(columns=['Transaction Date'],inplace=True)
df
# Out:
#            Name                      Email  \
# 0      PERSON_1         PERSON_1@gmail.com
# 1      PERSON_2  PERSON_2@tataprojects.com
# 2      PERSON_3         PERSON_3@gmail.com
# 3      PERSON_4         PERSON_4@gmail.com
# 4      PERSON_5         PERSON_5@gmail.com
# ..          ...                        ...
# 576  PERSON_522       PERSON_522@gmail.com
# 577  PERSON_523       PERSON_523@gmail.com
# 578  PERSON_523       PERSON_523@gmail.com
# 579  PERSON_524       PERSON_524@gmail.com
# 580  PERSON_525       PERSON_525@gmail.com
#
#                                                Product                Time  \
# 0                                           PRODUCT_75 2021-01-03 00:47:26
# 1                                           PRODUCT_75 2021-01-03 02:04:07
# 2                                           PRODUCT_63 2021-01-03 09:10:43
# 3                                           PRODUCT_63 2021-01-03 09:49:48
# ...

# %%
time = df['Hour'].value_counts().index.tolist()[:24]
amount = df["Hour"].value_counts().values.tolist()[:24]
sales = pd.DataFrame(({"Hour": time,"Amount of People" : amount}))
sales = sales.sort_values(by="Hour")
sales
# Out:
#     Hour  Amount of People
# 14     0                17
# 18     1                 4
# 19     2                 3
# 22     3                 1
# 20     5                 3
# 21     6                 2
# 17     7                 6
# 16     8                10
# 15     9                14
# 13    10                24
# 7     11                37
# 1     12                51
# 8     13                33
# 11    14                28
# 5     15                41
# 10    16                29
# 12    17                27
# 9     18                33
# 3     19                42
# 6     20                39
# 4     21                41
# 2     22                45
# 0     23                51

# %%
plt.figure(figsize=(20,10))
plt.plot(sales.Hour,sales["Amount of People"],'r')
plt.xlabel("Hours")
plt.ylabel("Amount of people")
plt.title("Phone sales for each hour")
plt.grid()
plt.show()

# %% [markdown]
# As you can see around midnight till 10 in the morning,amount of people who buy are the phone are under 30 and the peak is around 12 hour. It drops back again and peak at around 23 hour.
